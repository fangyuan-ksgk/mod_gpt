# %%
from src.rank_regularizer import * 

B, S, D = 2, 1024, 256 
Z = torch.randn(B, S, D)

b_idx = 1
hutchinson_power_estimator(Z[b_idx], 2)
# Out:
# tensor(5.3052)

# %%
calculate_matrix_based_entropy(Z[0]), calculate_matrix_based_entropy(Z[1])
# Out:
# (tensor(5.3221), tensor(5.3233))
